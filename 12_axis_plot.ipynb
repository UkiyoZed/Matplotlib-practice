# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]
y = [3, 2, 2, 3]

plt.plot(x, y, color="#000")

# plt.xticks(x, labels=["python", "c", "c++", "java"])
# plt.yticks(y)

# plt.xlim(0, 10)
# plt.ylim(0,10)

plt.axis([0,10,0,7])

plt.show()
