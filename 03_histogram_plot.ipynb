# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
x = np.random.randint(10, 60, (50))
print(x)
# Out:
# [40 23 37 51 37 40 56 17 53 36 46 43 28 24 54 12 18 48 53 33 30 37 51 57
#  53 52 54 28 37 18 20 15 44 34 40 31 51 59 15 26 55 19 32 52 29 37 24 13
#  43 11]

# %%
no = [40 ,23 ,37 ,51 ,37 ,40 ,56 ,17 ,53 ,36 ,46 ,43 ,28 ,24 ,54 ,12 ,18 ,48 ,53 ,33 ,30 ,37 ,51 ,57,
 53 ,52 ,54 ,28 ,37 ,18 ,20 ,15 ,44 ,34 ,40 ,31 ,51 ,59 ,15 ,26 ,55 ,19 ,32 ,52 ,29 ,37 ,24 ,13,
 43 ,11]

leng = [10, 20 , 30, 40, 50, 60] # range parameter

plt.hist(no, color="y",bins=leng, edgecolor='r', label="Python")

# plt.hist(no, color="b",bins=leng, edgecolor='r', log=True)
# plt.hist(no, color="b", edgecolor='r', rwidth=0.8)
# plt.hist(no, color="b", edgecolor='r', orientation="horizontal")
# plt.hist(no, color="b", edgecolor='r', histtype="step")
# plt.hist(no, color="b", edgecolor='r', align="mid")
# plt.hist(no, color="b", edgecolor='r', bottom=10)
# plt.hist(no, color="b", bins=leng, edgecolor='r', cumulative=-1)
# plt.hist(no, "auto", (0,60), edgecolor='r')

plt.title("Frequency of Histogram", fontsize=15)
plt.xlabel("Python", fontsize=12)
plt.ylabel("Numbers", fontsize=12)

plt.axvline(45, color="g", label="Line")

plt.legend()
plt.grid()
plt.show()
